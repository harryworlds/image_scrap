# %%
from importlib.resources import path
from pathlib import Path
from attr import attributes
from matplotlib.image import thumbnail
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests 
import io
import PIL 
from PIL import Image
import time

PATH = "C:\\Users\\heman\\Desktop\\Web_scrap\\chromedriver.exe"


driver = webdriver.Chrome(PATH)

def get_images_from_google(driver, delay, max_images):
	def scroll_down(driver):
		driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
		time.sleep(delay)

	url = input()
	driver.get(url)

	image_urls = set()
	skips = 0

	while len(image_urls) + skips < max_images:
		scroll_down(driver)

		thumbnails = driver.find_elements(By.CLASS_NAME, "Q4LuWd")

		for img in thumbnails[len(image_urls) + skips:max_images]:
			try:
				img.click()
				time.sleep(delay)
			except:
				continue

			images = driver.find_elements(By.CLASS_NAME, "n3VNCb")
			for image in images:
				if image.get_attribute('src') in image_urls:
					max_images += 1
					skips += 1
					break

				if image.get_attribute('src') and 'http' in image.get_attribute('src'):
					image_urls.add(image.get_attribute('src'))
				print(f"Image founded {len(image_urls)}")

	return image_urls


def download_image(download_path, url, file_name):
	try:
		image_content = requests.get(url).content
		image_file = io.BytesIO(image_content)
		image = Image.open(image_file)
		file_path = download_path + file_name

		with open(file_path, "driver") as f:
			image.save(f, "JPEG")

		print("download sucessfull")
	except Exception as e:
		print('Error -', e)
value = 5
urls = get_images_from_google(driver, 1, value)

for harryworlds, url in enumerate(urls):
	download_image("download_images/", url, str(harryworlds) + ".jpg")

driver.quit()
# Out:
# C:\Users\heman\AppData\Local\Temp\ipykernel_23500\623176819.py:17: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)
# Image founded 1
# Image founded 1
# Image founded 1
# Image founded 2
# Image founded 2
# Image founded 2
# Image founded 3
# Image founded 3
# Image founded 3
# Image founded 4
# Image founded 4
# Image founded 4
# Image founded 5
# Image founded 5
# Error - invalid mode: 'driver'
# Error - invalid mode: 'driver'
# Error - invalid mode: 'driver'
# Error - invalid mode: 'driver'
# Error - invalid mode: 'driver'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests
import io
from PIL import Image
import time


PATH = "C:\\Users\\heman\\Desktop\\Web_scrap\\chromedriver.exe"

wd = webdriver.Chrome(PATH)

def get_images_from_google(wd, delay, max_images):
	def scroll_down(wd):
		wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")
		time.sleep(delay)

	url = input()
	wd.get(url)

	image_urls = set()
	skips = 0

	while len(image_urls) + skips < max_images:
		scroll_down(wd)

		thumbnails = wd.find_elements(By.CLASS_NAME, "Q4LuWd")

		for img in thumbnails[len(image_urls) + skips:max_images]:
			try:
				img.click()
				time.sleep(delay)
			except:
				continue

			images = wd.find_elements(By.CLASS_NAME, "n3VNCb")
			for image in images:
				if image.get_attribute('src') in image_urls:
					max_images += 1
					skips += 1
					break

				if image.get_attribute('src') and 'http' in image.get_attribute('src'):
					image_urls.add(image.get_attribute('src'))
					print(f"Image {len(image_urls)}")

	return image_urls


def download_image(download_path, url, file_name):
	try:
		image_content = requests.get(url).content
		image_file = io.BytesIO(image_content)
		image = Image.open(image_file)
		file_path = download_path + file_name

		with open(file_path, "wb") as f:
			image.save(f, "JPEG")

		print("Success downloaded")
	except Exception as e:
		print('Error -', e)
initial_value = 1
final_value = 10
urls = get_images_from_google(wd, initial_value, final_value)

for harryworlds, url in enumerate(urls):
	download_image("download_images/", url, str(harryworlds) + ".jpg")
print(wd)
# Out:
# C:\Users\heman\AppData\Local\Temp\ipykernel_24124\3827361290.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome(PATH)
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# c:\Users\heman\Desktop\Web_scrap\main.ipynb Cell 2 in <cell line: 65>()
#      <a href='vscode-notebook-cell:/c%3A/Users/heman/Desktop/Web_scrap/main.ipynb#W1sZmlsZQ%3D%3D?line=62'>63</a> initial_value = 1
#      <a href='vscode-notebook-cell:/c%3A/Users/heman/Desktop/Web_scrap/main.ipynb#W1sZmlsZQ%3D%3D?line=63'>64</a> final_value = input()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/heman/Desktop/Web_scrap/main.ipynb#W1sZmlsZQ%3D%3D?line=64'>65</a> urls = get_images_from_google(wd, initial_value, final_value)
#      <a href='vscode-notebook-cell:/c%3A/Users/heman/Desktop/Web_scrap/main.ipynb#W1sZmlsZQ%3D%3D?line=66'>67</a> for harryworlds, url in enumerate(urls):
#      <a href='vscode-notebook-cell:/c%3A/Users/heman/Desktop/Web_scrap/main.ipynb#W1sZmlsZQ%3D%3D?line=67'>68</a> 	download_image("download_images/", url, str(harryworlds) + ".jpg")
#
# c:\Users\heman\Desktop\Web_scrap\main.ipynb Cell 2 in get_images_from_google(wd, delay, max_images)
#      <a href='vscode-notebook-cell:/c%3A/Users/heman/Desktop/Web_scrap/main.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a> 	time.sleep(delay)
#      <a href='vscode-notebook-cell:/c%3A/Users/heman/Desktop/Web_scrap/main.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a> url = input()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/heman/Desktop/Web_scrap/main.ipynb#W1sZmlsZQ%3D%3D?line=18'>19</a> wd.get(url)
#      <a href='vscode-notebook-cell:/c%3A/Users/heman/Desktop/Web_scrap/main.ipynb#W1sZmlsZQ%3D%3D?line=20'>21</a> image_urls = set()
#      <a href='vscode-notebook-cell:/c%3A/Users/heman/Desktop/Web_scrap/main.ipynb#W1sZmlsZQ%3D%3D?line=21'>22</a> skips = 0
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.get(self, url)
#     436 def get(self, url: str) -> None:
#     437     """
#     438     Loads a web page in the current browser session.
#     439     """
# --> 440     self.execute(Command.GET, {'url': url})
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: invalid argument
#   (Session info: chrome=105.0.5195.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x007CDF13+2219795]
# 	Ordinal0 [0x00762841+1779777]
# 	Ordinal0 [0x00674100+803072]
# 	Ordinal0 [0x0066760A+751114]
# 	Ordinal0 [0x006661A8+745896]
# 	Ordinal0 [0x006663FD+746493]
# 	Ordinal0 [0x00675A8E+809614]
# 	Ordinal0 [0x006CF87D+1177725]
# 	Ordinal0 [0x006BE7FC+1107964]
# 	Ordinal0 [0x006CF192+1175954]
# 	Ordinal0 [0x006BE616+1107478]
# 	Ordinal0 [0x00697F89+950153]
# 	Ordinal0 [0x00698F56+954198]
# 	GetHandleVerifier [0x00AC2CB2+3040210]
# 	GetHandleVerifier [0x00AB2BB4+2974420]
# 	GetHandleVerifier [0x00866A0A+565546]
# 	GetHandleVerifier [0x00865680+560544]
# 	Ordinal0 [0x00769A5C+1808988]
# 	Ordinal0 [0x0076E3A8+1827752]
# 	Ordinal0 [0x0076E495+1827989]
# 	Ordinal0 [0x007780A4+1867940]
# 	BaseThreadInitThunk [0x768A6739+25]
# 	RtlGetFullPathName_UEx [0x773F90AF+1215]
# 	RtlGetFullPathName_UEx [0x773F907D+1165]
